# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishachouhan019/Pandas-Data-Analysis-Lab/blob/main/Pandas_Class5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 5: Sorting & Basic Statistics
# Welcome to **Class 5** of our Pandas series. Today we’ll learn how to sort data and calculate basic statistics.

# %% [markdown]
# ## 1. Sorting Data
# - Use `sort_values(by='col')` to sort by column values.
# - Use `ascending=False` for descending order.
# - Sort by multiple columns by passing a list.
# - `sort_index()` sorts by row or column index.

# %%
import pandas as pd
data = {
    "Product" : ['Pen','Notebook','Pencil','Marker','Erasor','Sharpener'],
    'Price' : [10,50,5,30,8,12],
    'Stoke' : [100,60,200,80,150,120],
    'Rating' : [4.5,4.7,4.2,4.8,4.3,4.4]
}
df = pd.DataFrame(data)

#1.Sort by a single column -> price ,acrnding order
print(df.sort_values(by='Price'))

#2. Sort by a single column -> Rating, desending
print(df.sort_values(by='Rating',ascending=False))

#3.Sort by multiple columns -> Price and stock
df.sort_values(by=['Price','Stoke'])

#4.Sort index -> in descending order
print(df.sort_index(ascending=False))
# Out:
#      Product  Price  Stoke  Rating
# 2     Pencil      5    200     4.2
# 4     Erasor      8    150     4.3
# 0        Pen     10    100     4.5
# 5  Sharpener     12    120     4.4
# 3     Marker     30     80     4.8
# 1   Notebook     50     60     4.7
#      Product  Price  Stoke  Rating
# 3     Marker     30     80     4.8
# 1   Notebook     50     60     4.7
# 0        Pen     10    100     4.5
# 5  Sharpener     12    120     4.4
# 4     Erasor      8    150     4.3
# 2     Pencil      5    200     4.2
#      Product  Price  Stoke  Rating
# 5  Sharpener     12    120     4.4
# 4     Erasor      8    150     4.3
# 3     Marker     30     80     4.8
# 2     Pencil      5    200     4.2
# 1   Notebook     50     60     4.7
# 0        Pen     10    100     4.5

# %% [markdown]
# ## 2. Descriptive Statistics
# - `mean()`, `median()`, `mode()` for central tendency.
# - `std()` for standard deviation.
# - `describe()` for a summary of stats (count, mean, std, min, quartiles, max).

# %%
print(df)

#1. Mean of numeric columns only
print(df.mean(numeric_only=True))

#2. Median
print(df.median(numeric_only=True))

#3. Mode
print(df.mode())

#4. Standard deviation
print(df.std(numeric_only=True))

#5. Complete Statistical Values of columns (Summary of stats)
print(df.describe())
# Out:
#      Product  Price  Stoke  Rating
# 0        Pen     10    100     4.5
# 1   Notebook     50     60     4.7
# 2     Pencil      5    200     4.2
# 3     Marker     30     80     4.8
# 4     Erasor      8    150     4.3
# 5  Sharpener     12    120     4.4
# Price      19.166667
# Stoke     118.333333
# Rating      4.483333
# dtype: float64
# Price      11.00
# Stoke     110.00
# Rating      4.45
# dtype: float64
#      Product  Price  Stoke  Rating
# 0     Erasor      5     60     4.2
# 1     Marker      8     80     4.3
# 2   Notebook     10    100     4.4
# 3        Pen     12    120     4.5
# 4     Pencil     30    150     4.7
# 5  Sharpener     50    200     4.8
# Price     17.486185
# Stoke     50.760877
# Rating     0.231661
# dtype: float64
#            Price       Stoke    Rating
# count   6.000000    6.000000  6.000000
# mean   19.166667  118.333333  4.483333
# std    17.486185   50.760877  0.231661
# min     5.000000   60.000000  4.200000
# 25%     8.500000   85.000000  4.325000
# 50%    11.000000  110.000000  4.450000
# 75%    25.500000  142.500000  4.650000
# max    50.000000  200.000000  4.800000

# %% [markdown]
# ## 3. Counting Values
# - `value_counts()` shows the frequency of unique values in a Series.
# - Use `normalize=True` to see percentages instead of counts.

# %%
print(df)
#1. Count how many time each product appears
print(df['Product'].value_counts())

#2. Count how many time each product appears in percentage
print(df['Product'].value_counts(normalize=True))

#3. count values for column Rating
print(df['Rating'].value_counts())
# Out:
#      Product  Price  Stoke  Rating
# 0        Pen     10    100     4.5
# 1   Notebook     50     60     4.7
# 2     Pencil      5    200     4.2
# 3     Marker     30     80     4.8
# 4     Erasor      8    150     4.3
# 5  Sharpener     12    120     4.4
# Product
# Pen          1
# Notebook     1
# Pencil       1
# Marker       1
# Erasor       1
# Sharpener    1
# Name: count, dtype: int64
# Product
# Pen          0.166667
# Notebook     0.166667
# Pencil       0.166667
# Marker       0.166667
# Erasor       0.166667
# Sharpener    0.166667
# Name: proportion, dtype: float64
# Rating
# 4.5    1
# 4.7    1
# 4.2    1
# 4.8    1
# 4.3    1
# 4.4    1
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Correlation & Covariance
# - `corr()` computes correlation between numeric columns.
# - `cov()` computes covariance.
# - Correlation values range from -1 (negative) to +1 (positive).

# %%
#1. Correaltion between all numeric column.
print(df.corr(numeric_only=True))
#-ve correlation -> one increases 2nd decreases
#+ve correaltion -> one incerases other incerases

#2. Covariance between all numeric column.
print(df.cov(numeric_only=True))

#3. correaltion between 2 specific column
print(df['Price'].corr(df['Stoke']))
# Out:
#            Price     Stoke    Rating
# Price   1.000000 -0.804028  0.820402
# Stoke  -0.804028  1.000000 -0.921257
# Rating  0.820402 -0.921257  1.000000
#              Price        Stoke     Rating
# Price   305.766667  -713.666667   3.323333
# Stoke  -713.666667  2576.666667 -10.833333
# Rating    3.323333   -10.833333   0.053667
# -0.8040280933316356

# %% [markdown]
# ## Mini Practice
# 1. Build a DataFrame with columns: Name, Age, Score, Height.
# 2. Sort the data by Score (descending).
# 3. Get mean, median, mode, and std of numeric columns.
# 4. Use value_counts on Name or any categorical column.
# 5. Compute corr() and cov() for all numeric columns.

# %%
# Write your mini practice solution here

# 1. Build a DataFrame with columns: Name, Age, Score, Height
import pandas as pd
data = {
    "Name" : ['Alice','Bob','Charlie','David','Eve'],
    "Age" : [25,30,22,28,35],
    "Score" : [85,92,78,95,97],
    "Height" : [165,170,160,175,180]
}
df = pd.DataFrame(data)
print(df)


# 2. Sort the data by Score (descending)
print(df.sort_values(by='Score',ascending=False))

# 3. Get mean, median, mode, and std of numeric columns
print(df.mean(numeric_only=True))
print(df.median(numeric_only=True))
print(df.mode())
print(df.std(numeric_only=True))

# 4. Use value_counts on Name or any categorical column
print(df['Name'].value_counts())

# 5. Compute corr() and cov() for all numeric columns
print(df.corr(numeric_only=True))
print(df.cov(numeric_only=True))
# Out:
#       Name  Age  Score  Height
# 0    Alice   25     85     165
# 1      Bob   30     92     170
# 2  Charlie   22     78     160
# 3    David   28     95     175
# 4      Eve   35     97     180
#       Name  Age  Score  Height
# 4      Eve   35     97     180
# 3    David   28     95     175
# 1      Bob   30     92     170
# 0    Alice   25     85     165
# 2  Charlie   22     78     160
# Age        28.0
# Score      89.4
# Height    170.0
# dtype: float64
# Age        28.0
# Score      92.0
# Height    170.0
# dtype: float64
#       Name  Age  Score  Height
# 0    Alice   22     78     160
# 1      Bob   25     85     165
# 2  Charlie   28     92     170
# 3    David   30     95     175
# 4      Eve   35     97     180
# Age       4.949747
# Score     7.829432
# Height    7.905694
# dtype: float64
# Name
# Alice      1
# Bob        1
# Charlie    1
# David      1
# Eve        1
# Name: count, dtype: int64
#              Age     Score    Height
# Age     1.000000  0.903139  0.926371
# Score   0.903139  1.000000  0.969351
# Height  0.926371  0.969351  1.000000
#           Age  Score  Height
# Age     24.50   35.0   36.25
# Score   35.00   61.3   60.00
# Height  36.25   60.0   62.50

# %% [markdown]
# ---
# ## Summary
# - Learned to sort by columns with `sort_values` and by index with `sort_index`.
# - Explored descriptive statistics: mean, median, mode, std, describe.
# - Counted values with `value_counts`.
# - Calculated correlation and covariance.
