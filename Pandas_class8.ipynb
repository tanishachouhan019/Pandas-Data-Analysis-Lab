# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishachouhan019/Pandas-Data-Analysis-Lab/blob/main/Pandas_class8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 8: Working with Time Series
# Welcome to **Class 8** of our Pandas series. Today we’ll learn how to handle and analyze time series data.

# %% [markdown]
# ## 1. Converting Columns to Datetime (`pd.to_datetime`)
# - Use `pd.to_datetime()` to convert strings or numbers into datetime objects.
# - Once converted, Pandas recognizes them as dates, enabling powerful operations.

# %%
import pandas as pd

# 1. Create the dataset
data = {
    "OrderID": [1001, 1002, 1003, 1004, 1005],
    "OrderDate": ["2024-01-05", "2024/01/12", "15-01-2024", "2024-01-20", "20240125"],
    "Customer": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Amount": [250, 400, 150, 300, 500]
}
df = pd.DataFrame(data)

df['OrderDate'] = pd.to_datetime(df['OrderDate'], format='mixed', errors='coerce')  #standared format -> year-month-date
print(df)
# Out:
#    OrderID  OrderDate Customer  Amount
# 0     1001 2024-01-05    Alice     250
# 1     1002 2024-01-12      Bob     400
# 2     1003 2024-01-15  Charlie     150
# 3     1004 2024-01-20    David     300
# 4     1005 2024-01-25     Emma     500

# %%
pd.to_datetime(df['OrderDate'],errors='coerce',format='mixed').dt.strftime('%d-%m-%Y')
# Out:
# 0    05-01-2024
# 1    12-01-2024
# 2    15-01-2024
# 3    20-01-2024
# 4    25-01-2024
# Name: OrderDate, dtype: object

# %% [markdown]
# ## 2. Setting DateTime Index & Resampling
# - Set a datetime column as the index with `set_index()`.
# - Resample time series using `resample('M').mean()` or other rules ('D', 'W', 'Y').
# - Useful for aggregating data by time periods.

# %%
print(df)
#step1 -> Orderdate set as Index
df_idx = df.set_index('OrderDate')

#step2: We will resample complete data
#accounding to months and we will get the total
#ammount of the month.
monthly_amount = df_idx.resample('ME')['Amount'].sum()
print(monthly_amount)
#year avg
yearly_avg = df_idx.resample('YE')['Amount'].mean()
print(yearly_avg)

#WEEK AVG
week_average = df_idx.resample('W')['Amount'].mean()
print(week_average)
# Out:
#    OrderID  OrderDate Customer  Amount
# 0     1001 2024-01-05    Alice     250
# 1     1002 2024-01-12      Bob     400
# 2     1003 2024-01-15  Charlie     150
# 3     1004 2024-01-20    David     300
# 4     1005 2024-01-25     Emma     500
# OrderDate
# 2024-01-31    1600
# Freq: ME, Name: Amount, dtype: int64
# OrderDate
# 2024-12-31    320.0
# Freq: YE-DEC, Name: Amount, dtype: float64
# OrderDate
# 2024-01-07    250.0
# 2024-01-14    400.0
# 2024-01-21    225.0
# 2024-01-28    500.0
# Freq: W-SUN, Name: Amount, dtype: float64

# %% [markdown]
# ## mini-project
#
# Converting columns to datetime (pd.to_datetime)
#
# Setting a DateTime index & resampling

# %%
import pandas as pd
# 1️⃣ Create a dataset of website visits (string dates + visit counts)
data = {
    "VisitDate": ["2023-01-01", "20230102", "2023-01-03", "2023/01/04", "2023-01-05"],
    "Visits": [10, 15, 8, 12, 14]
}
df = pd.DataFrame(data)
print(df)

# 2️⃣ Convert VisitDate to datetime
df['VisitDate'] = pd.to_datetime(df['VisitDate'], format='mixed', errors='coerce')
print(df)

# 3️⃣ Set VisitDate as the index
df.set_index('VisitDate', inplace=True)
print(df)

# 4️⃣ Resample to get total visitors per month
monthly_visitors = df.resample('M')['Visits'].sum()
print(monthly_visitors)

# 5️⃣ Resample to get average visitors per week
weekly_avg = df.resample('W')['Visits'].mean()
print(weekly_avg)
# Out:
#     VisitDate  Visits
# 0  2023-01-01      10
# 1    20230102      15
# 2  2023-01-03       8
# 3  2023/01/04      12
# 4  2023-01-05      14
#    VisitDate  Visits
# 0 2023-01-01      10
# 1 2023-01-02      15
# 2 2023-01-03       8
# 3 2023-01-04      12
# 4 2023-01-05      14
#             Visits
# VisitDate
# 2023-01-01      10
# 2023-01-02      15
# 2023-01-03       8
# 2023-01-04      12
# 2023-01-05      14
# VisitDate
# 2023-01-31    59
# Freq: ME, Name: Visits, dtype: int64
# VisitDate
# 2023-01-01    10.00
# 2023-01-08    12.25
# Freq: W-SUN, Name: Visits, dtype: float64
# /tmp/ipykernel_3394/298888289.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_visitors = df.resample('M')['Visits'].sum()

# %% [markdown]
# ---
# ## Summary
# - Converted columns to datetime with `pd.to_datetime`.
# - Set DateTime index and resampled data.
# - Performed date-based filtering and slicing.
# - Applied rolling and expanding window calculations.
