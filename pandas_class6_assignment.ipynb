# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishachouhan019/Pandas-Data-Analysis-Lab/blob/main/pandas_class6_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Class 6 Assignment
#
# ## Level: Basic to Intermediate
#
# ### Instructions
# - Solve all questions using Pandas.
# - Write code in the blank code cell below each question.
# - Print the required output.

# %% [markdown]
# # Q1. Display Unique Values
#
# ## Problem Statement
# Create a DataFrame with a City column and display all unique cities.
#
# ## Sample Input
# ```python
# City = ["Bhopal", "Indore", "Bhopal", "Delhi"]
# ```
#
# ## Sample Output
# ```python
# ['Bhopal' 'Indore' 'Delhi']
# ```

# %%
import pandas as pd

data = {'City': ['Bhopal', 'Indore', 'Bhopal', 'Delhi']}
df = pd.DataFrame(data)

unique_cities = df['City'].unique()
print(unique_cities)
# Out:
# ['Bhopal' 'Indore' 'Delhi']

# %% [markdown]
# # Q2. Count Unique Values
#
# ## Problem Statement
# Find the number of unique cities in a DataFrame.
#
# ## Sample Input
# ```python
# City = ["Bhopal", "Indore", "Bhopal", "Delhi"]
# ```
#
# ## Sample Output
# ```python
# 3
# ```

# %%
print(df['City'].nunique())
# Out:
# 3

# %% [markdown]
# # Q3. Value Counts
#
# ## Problem Statement
# Count occurrences of each city.
#
# ## Sample Input
# ```python
# City = ["Bhopal", "Indore", "Bhopal", "Delhi"]
# ```
#
# ## Sample Output
# ```python
# Bhopal    2
# Indore    1
# Delhi     1
# ```

# %%
print(df['City'].value_counts())
# Out:
# City
# Bhopal    2
# Indore    1
# Delhi     1
# Name: count, dtype: int64

# %% [markdown]
# # Q4. Group By City
#
# ## Problem Statement
# Find average marks city-wise using groupby().
#
# ## Sample Input
# ```python
# City   Marks
# Bhopal 80
# Bhopal 90
# Delhi  70
# ```
#
# ## Sample Output
# ```python
# Bhopal 85
# Delhi  70
# ```

# %%
import pandas as pd
data = {
    'City': ['Bhopal', 'Bhopal', 'Delhi'],
    'Marks': [80, 90, 70,],
    'Age' : [25,30,35]}

df = pd.DataFrame(data)
print(df.groupby('City')['Marks'].mean())
# Out:
# City
# Bhopal    85.0
# Delhi     70.0
# Name: Marks, dtype: float64

# %% [markdown]
# # Q5. Sort Values
#
# ## Problem Statement
# Sort students by Marks in ascending order.
#
# ## Sample Output
# ```python
# Sorted DataFrame
# ```

# %%
print(df.sort_values(by='Marks'))
# Out:
#      City  Marks  Age
# 2   Delhi     70   35
# 0  Bhopal     80   25
# 1  Bhopal     90   30

# %% [markdown]
# # Q6. Sort Values Descending
#
# ## Problem Statement
# Sort students by Marks in descending order.
#
# ## Sample Output
# ```python
# Sorted DataFrame
# ```

# %%
print(df.sort_values(by='Marks',ascending=False))
# Out:
#      City  Marks  Age
# 1  Bhopal     90   30
# 0  Bhopal     80   25
# 2   Delhi     70   35

# %% [markdown]
# # Q7. Filter Records
#
# ## Problem Statement
# Display students having marks greater than 75.
#
# ## Sample Output
# ```python
# Filtered rows
# ```

# %%
print(df[df['Marks']>75])
# Out:
#      City  Marks  Age
# 0  Bhopal     80   25
# 1  Bhopal     90   30

# %% [markdown]
# # Q8. Multiple Conditions
#
# ## Problem Statement
# Display students whose marks are greater than 70 and age is greater than 20.
#
# ## Sample Output
# ```python
# Filtered rows
# ```

# %%
print(df[(df['Marks']>70) & (df['Age']>20)])
# Out:
#      City  Marks  Age
# 0  Bhopal     80   25
# 1  Bhopal     90   30

# %% [markdown]
# # Q9. Group By Department
#
# ## Problem Statement
# Create Employee and Department data and find total salary department-wise.
#
# ## Sample Output
# ```python
# HR       50000
# IT      120000
# ```

# %%
Data = {'Employee': ['John', 'Jane', 'Mike'],
        'Department': ['HR', 'IT', 'IT'],
        'Salary': [50000, 60000, 60000]
        }
print(Data)
df = pd.DataFrame(Data)
print(df.groupby('Department')['Salary'].sum())
# Out:
# {'Employee': ['John', 'Jane', 'Mike'], 'Department': ['HR', 'IT', 'IT'], 'Salary': [50000, 60000, 60000]}
# Department
# HR     50000
# IT    120000
# Name: Salary, dtype: int64

# %% [markdown]
# # Q10. Complete Practice Question
#
# ## Problem Statement
# Create a DataFrame containing:
# - Name
# - Age
# - City
# - Marks
#
# Perform:
# 1. Show unique cities
# 2. Count city frequency
# 3. Filter marks > 80
# 4. Sort by marks
#
# ## Sample Output
# ```python
# Required Results
# ```

# %%
DataF = {'Name': ['John', 'Jane', 'Mike'],
        'Age': [25, 30, 35],
        'City': ['Bhopal', 'Indore', 'Bhopal'],
        'Marks': [80, 90, 70]
        }
df = pd.DataFrame(DataF)
print(df)
print(df['City'].unique())
print(df['City'].value_counts())
print(df[df['Marks']>80])
print(df.sort_values(by='Marks'))
# Out:
#    Name  Age    City  Marks
# 0  John   25  Bhopal     80
# 1  Jane   30  Indore     90
# 2  Mike   35  Bhopal     70
# ['Bhopal' 'Indore']
# City
# Bhopal    2
# Indore    1
# Name: count, dtype: int64
#    Name  Age    City  Marks
# 1  Jane   30  Indore     90
#    Name  Age    City  Marks
# 2  Mike   35  Bhopal     70
# 0  John   25  Bhopal     80
# 1  Jane   30  Indore     90
